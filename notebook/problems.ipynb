# %% [markdown]
# # Probability exercises

# %% [markdown]
# ### Exercise 1
#
# Two unbiased dice are thrown once and the total score is observed. Use a simulation to find the estimated probability that the total score is even or greater than 7
#
# We could use a mathematical equation to solve this or we can run the experiment many times, and then count the number of times where the score is even or greater than 7
#
# -Run the experiment 1000 times (roll 2 dice 1000 times, and sum the result)
#
# -Keep track of the number of times that the sum was either greater than 7 or an even number
#
# -Divide the number from step 2 by the number of iterations (1000)

# %%
#import libraries

import random

# creo el contador

c7 = 0
n = 1000
for i in range(n):
    resultado = random.randint(1,6) + random.randint(1,6)
    if resultado > 7 or resultado % 2 == 0:
        c7 = c7 + 1
    
print("La probabilidad de ser mayor que 7 o ser un numero par es: ", c7*100/n,"%")
# Out:
# La probabilidad de ser mayor que 7 o ser un numero par es:  66.8 %

# %%
#funcion del lanzamiento
x = random.randint(1,7)
y = random.randint(1,7)

def lanzamiento_dados():
    for i in range(1000):
        print (x + y)
resultado = print(x + y)
# Out:
# 7

# %% [markdown]
# ### Exercise 2
#
# A box contains 10 white balls, 20 reds and 30 greens. Draw 5 balls with replacement. What is the probability that:
#
# a. 3 white or 2 red
#
# b. All 5 are the same color
#
#
# We will use the same system here. We will pick our balls during each round and count the number of times that:
#
# a. 3 white or 2 red
#
# b. All 5 are the same color.

# %%
#import libraries
import random
import numpy as np

bolas = {}

for i in range(60):
    if i < 10:
        bolas[i] = 'blanco'
    elif i > 9 and i < 30:
        bolas[i] = 'Rojo'
    else:
        bolas[i] = 'verde'  

#contenedores
experimento_1 = 0
experimento_2 = 0
n_simulaciones = 1000

#iterador
def iterador():
    for i in range(n_simulaciones):
        salio = []
        for i in range(5):
            salio.append(bolas[random.randint(0,59)])
    
#Convert it to a numpy array
        salio = np.array(salio)

#find the number of each taht we picked
        blanco = sum(salio == 'blanco')
        Rojo = sum(salio == 'Rojo')
        verde = sum(salio == 'verde')

#experimento 1

    if blanco == 3 or Rojo == 2:
        experimento_1 += 1
    if blanco == 5 or Rojo == 5 or verde == 5:
        experimento_2 += 1
print(experimento_2)

print("La probabilidad de 3 blanco y 2 rojas es: ", experimento_1/n_simulaciones*100,"%")
print("La probabilidad de todas blanco o todas rojo es: ", experimento_2/n_simulaciones*100,"%")
# Out:
# 0
# La probabilidad de 3 blanco y 2 rojas es:  0.0 %
# La probabilidad de todas blanco o todas rojo es:  0.0 %

# %%
#import libraries_ segundo intento
import random
import numpy as np

bolas = {}

for i in range(60):
    if i < 10:
        bolas[i] = 'blanco'
    elif i > 9 and i < 30:
        bolas[i] = 'Rojo'
    else:
        bolas[i] = 'verde'  

# creo el contador
blanco = 0
Rojo = 0
verde = 0
n = 60
for i in range(5):
    caja = random.randint(0,60)
    if caja < 10:
        blanco = blanco + 1
    elif caja >= 10 and caja < 30:
        Rojo = Rojo + 1 
    else:
        verde = verde + 1

caja = blanco + Rojo + verde

print(caja)

np.random.seed(100)
#contenedores_2
experimento_1 = 0
experimento_2 = 0
n_simulaciones = 1000

for i in range(n_simulaciones):
    caja = np.array(caja)
    for i in range(5):
#experimentos
        if caja == blanco == 3 and Rojo == 2:
            experimento_1 += 1
        if caja == blanco == 5 or Rojo == 5 or verde == 5:
            experimento_2 += 1

Probabilidad_experi_1 = experimento_1/n_simulaciones
print(Probabilidad_experi_1)
print("La probabilidad de 3 blanco y 2 rojas es: ", experimento_1*100/n_simulaciones,"%")
# Out:
# 5
# 0.0
# La probabilidad de 3 blanco y 2 rojas es:  0.0 %

# %%
#import libraries

import random
import numpy as np

# creo el contador
bolas_blancas = 0
bolas_rojas = 0
bolas_verdes = 0
n = 60
for i in range(5):
    caja = random.randint(0,60)
    if caja < 10:
        bolas_blancas = bolas_blancas + 1
    elif caja >= 10 and caja < 30:
        bolas_rojas = bolas_rojas + 1 
    else:
        bolas_verdes = bolas_verdes + 1

print("La probabilidad de ser blancas es: ", (bolas_blancas/n)*100,"%")
print("La probabilidad de ser rojas es: ", (bolas_rojas/n)*100,"%")
print("La probabilidad de ser verdes es: ", (bolas_verdes/n)*100,"%")
# Out:
# La probabilidad de ser blancas es:  0.0 %
# La probabilidad de ser rojas es:  0.0 %
# La probabilidad de ser verdes es:  8.333333333333332 %

# %%
# importo librerias 
import random

# defino las variables
evento = range(1,6)

def experimento_bolas():
    bolas_blancas1 = random.randint(1,10)
    bolas_rojas1 = random.randint(11,20)
    bolas_verdes1 = random.randint(21,60)
    return[bolas_blancas1,bolas_rojas1,bolas_verdes1]
 
experimento_bolas()
# Out:
# [5, 12, 41]

# %%
# importo librerias 
import random


def experimento_bolas():
    bol = random.randint(1,60)
    return bol
experimento_bolas()
# Out:
# 46
